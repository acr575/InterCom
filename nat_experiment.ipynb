# %% [markdown]
# # Experimento tipo de NAT

# %%
import stun

## Servidores stun de los que se obtiene respuesta
stun_servers = ['stun.12connect.com', 'stun.12voip.com', 'stun.aa.net.uk', 'stun.acrobits.cz', 'stun.actionvoip.com', 'stun.aeta-audio.com', 'stun.aeta.com', 'stun.antisip.com', 'stun.cheapvoip.com', 'stun.commpeak.com']

## Función para hacer peticiones a los servidores stun
def queryServers():
    print("Respuestas:\n")
    for server in stun_servers:
        nat_type, external_ip, external_port = stun.get_ip_info(stun_host=server)
        print(server, nat_type, external_ip, external_port)

# %% [markdown]
# ## Red de la UAL (eduroam)

# %%
queryServers()
# Out:
# Respuestas:
#
# stun.12connect.com Blocked None None
# stun.12voip.com Full Cone 150.214.223.70 54320
# stun.aa.net.uk Full Cone 150.214.223.70 54320
# stun.acrobits.cz Full Cone 150.214.223.70 54320
# stun.actionvoip.com Full Cone 150.214.223.70 54320
# stun.aeta-audio.com Full Cone 150.214.223.70 54320
# stun.aeta.com Full Cone 150.214.223.70 54320
# stun.antisip.com Full Cone 150.214.223.70 54320
# stun.cheapvoip.com Full Cone 150.214.223.70 54320

# %% [markdown]
# ## Red Ángel
